# %%
# !pip install onnx-simplifier
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting onnx-simplifier
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/60/06/61158244f2dc649283f559be3a80edeff4eaf213d195197331a914c0d70f/onnx_simplifier-0.4.33-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 13.8 MB/s eta 0:00:00 0:00:01
# Collecting onnx
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/b7/51/2959fa869df05a311f34fda01e7e876593a1a5daffe3ab01b2d60b6e0821/onnx-1.14.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 39.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: rich in /usr/local/envs/ssenv/lib/python3.9/site-packages (from onnx-simplifier) (13.4.2)
# Collecting protobuf>=3.20.2
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/01/cb/445b3e465abdb8042a41957dc8f60c54620dc7540dbcf9b458a921531ca2/protobuf-4.23.4-cp37-abi3-manylinux2014_x86_64.whl (304 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 313.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/envs/ssenv/lib/python3.9/site-packages (from onnx->onnx-simplifier) (4.3.0)
# Requirement already satisfied: numpy in /usr/local/envs/ssenv/lib/python3.9/site-packages (from onnx->onnx-simplifier) (1.22.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/envs/ssenv/lib/python3.9/site-packages (from rich->onnx-simplifier) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/envs/ssenv/lib/python3.9/site-packages (from rich->onnx-simplifier) (2.13.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/envs/ssenv/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->onnx-simplifier) (0.1.2)
# Installing collected packages: protobuf, onnx, onnx-simplifier
# Successfully installed onnx-1.14.0 onnx-simplifier-0.4.33 protobuf-4.23.4

# %%
# !pip install --upgrade torch
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: torch in /usr/local/envs/ssenv/lib/python3.9/site-packages (1.10.1)
# ^C
# ERROR: Operation cancelled by user

# %%
# !python mmyolo/projects/easydeploy/tools/export.py \
	mmyolo/configs/yolov5/yolov5_s-v61_fast_1xb12-40e_image.py \
	work_dirs/yolov5_s-v61_fast_1xb12-40e_image/best_coco_bbox_mAP_epoch_40.pth \
	--work-dir work_dirs/yolov5_s-v61_fast_1xb12-40e_image \
    --img-size 640 640 \
    --batch 1 \
    --device cpu \
    --simplify \
	--opset 11 \
	--backend 1 \
	--pre-topk 1000 \
	--keep-topk 100 \
	--iou-threshold 0.65 \
	--score-threshold 0.25
# Out:
# !!!You are using `YOLOv5Head` with num_classes == 1. The loss_cls will be 0. This is a normal phenomenon.
# Loads checkpoint by local backend from path: work_dirs/yolov5_s-v61_fast_1xb12-40e_image/best_coco_bbox_mAP_epoch_40.pth
# 08/05 13:02:46 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 08/05 13:02:46 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# ONNX export success, save into work_dirs/yolov5_s-v61_fast_1xb12-40e_image/end2end.onnx

# %%
# !pip install mmdet==3.0.0rc6
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: mmdet==3.0.0rc6 in /usr/local/envs/ssenv/lib/python3.9/site-packages (3.0.0rc6)
# Requirement already satisfied: pycocotools in /usr/local/envs/ssenv/lib/python3.9/site-packages (from mmdet==3.0.0rc6) (2.0.4)
# Requirement already satisfied: six in /usr/local/envs/ssenv/lib/python3.9/site-packages (from mmdet==3.0.0rc6) (1.16.0)
# Requirement already satisfied: matplotlib in /usr/local/envs/ssenv/lib/python3.9/site-packages (from mmdet==3.0.0rc6) (3.5.3)
# Requirement already satisfied: terminaltables in /usr/local/envs/ssenv/lib/python3.9/site-packages (from mmdet==3.0.0rc6) (3.1.10)
# Requirement already satisfied: numpy in /usr/local/envs/ssenv/lib/python3.9/site-packages (from mmdet==3.0.0rc6) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/envs/ssenv/lib/python3.9/site-packages (from mmdet==3.0.0rc6) (1.9.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/envs/ssenv/lib/python3.9/site-packages (from matplotlib->mmdet==3.0.0rc6) (4.36.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/envs/ssenv/lib/python3.9/site-packages (from matplotlib->mmdet==3.0.0rc6) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/envs/ssenv/lib/python3.9/site-packages (from matplotlib->mmdet==3.0.0rc6) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/envs/ssenv/lib/python3.9/site-packages (from matplotlib->mmdet==3.0.0rc6) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/envs/ssenv/lib/python3.9/site-packages (from matplotlib->mmdet==3.0.0rc6) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/envs/ssenv/lib/python3.9/site-packages (from matplotlib->mmdet==3.0.0rc6) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/envs/ssenv/lib/python3.9/site-packages (from matplotlib->mmdet==3.0.0rc6) (3.0.9)

# %%
# !pip install onnxruntime
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting onnxruntime
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/50/d5/f156d808c9cc59e7a8b87843a5313719d01eec7d3b17ca3f6b6f0fbee0f0/onnxruntime-1.15.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 28.7 MB/s eta 0:00:00a 0:00:01
# Collecting flatbuffers
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/6f/12/d5c79ee252793ffe845d58a913197bfa02ae9a0b5c9bc3dc4b58d477b9e7/flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: packaging in /usr/local/envs/ssenv/lib/python3.9/site-packages (from onnxruntime) (21.3)
# Collecting sympy
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/d2/05/e6600db80270777c4a64238a98d442f0fd07cc8915be2a1c16da7f2b9e74/sympy-1.12-py3-none-any.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 143.7 MB/s eta 0:00:00a 0:00:01
# Collecting coloredlogs
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/a7/06/3d6badcf13db419e25b07041d9c7b4a2c331d3f4e7134445ec5df57714cd/coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 201.3 MB/s eta 0:00:00
# Requirement already satisfied: protobuf in /usr/local/envs/ssenv/lib/python3.9/site-packages (from onnxruntime) (4.23.4)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/envs/ssenv/lib/python3.9/site-packages (from onnxruntime) (1.22.4)
# Collecting humanfriendly>=9.1
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/f0/0f/310fb31e39e2d734ccaa2c0fb981ee41f7bd5056ce9bc29b2248bd569169/humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 253.2 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/envs/ssenv/lib/python3.9/site-packages (from packaging->onnxruntime) (3.0.9)
# Collecting mpmath>=0.19
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/43/e3/7d92a15f894aa0c9c4b49b8ee9ac9850d6e63b03c9c32c0367a13ae62209/mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 316.5 MB/s eta 0:00:00
# Installing collected packages: mpmath, flatbuffers, sympy, humanfriendly, coloredlogs, onnxruntime
# Successfully installed coloredlogs-15.0.1 flatbuffers-23.5.26 humanfriendly-10.0 mpmath-1.3.0 onnxruntime-1.15.1 sympy-1.12

# %%
import onnxruntime

# %%
# !python mmyolo/projects/easydeploy/tools/image-demo.py \
    000697.png \
    mmyolo/configs/yolov5/yolov5_s-v61_fast_1xb12-40e_image.py \
    image.onnx \
--device cpu
# Out:
# [                                                  ] 0/1, elapsed: 0s, ETA:tensor([0.4860])
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 1/1, 0.3 task/s, elapsed: 3s, ETA:     0s
